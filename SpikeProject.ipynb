# %%
import os
import zipfile
import matplotlib.pyplot as plt
import neo.io as ni
import neo as n
import zipfile
from neo.io import Spike2IO
import numpy as np
import inspect
import spikeinterface.full as si
import hdbscan
from probeinterface import generate_linear_probe
from probeinterface import Probe
from probeinterface.plotting import plot_probe
import probeinterface as pi
import spikeinterface.sortingcomponents as sc

# %% [markdown]
# The experiment conducted at GIN, showcases how two groups of mouse, one control and other having Parkinsons Disease, show noiceptive response because of the footshock they receive. The first group is control group where the Substantia Niagra reticulate(SNr) has firing rate which is regular and tonic. The second group consists of mice have been injected with OHDA virus which creates dengeracy of neurons of Subtantia Niagra par compacta (SNc), which we observe in the Parkinson disease patients. The second group should show the high volatility in tonic and freeucny of both noiceptive response and optogenetic stimulation recepted by the SNr and consequently we get to see the noiceptive reponse in Superior Calliculus (SC).
#
# Below are the two extracellular recording got from both groups. We use Spike2extractor for both the recording to gather surfacial understanding of the signals and also to run preliminary trials on the signals.

# %%
data_loc = r"D:\GIPSA Labwork Internship\spiekee\Spikeme\sourcedata\520\ieeg\520-06.smr"
data_loc2 = r"D:\GIPSA Labwork Internship\spike_interface_primaries\RAWAT\Spikeme\Spikeme\sourcedata\502\ieeg\502-01.smr"

# %% [markdown]
# By default spike2 extractor shows both recorded channels

# %%
full_raw_control = si.read_spike2(data_loc)
full_raw_PD = si.read_spike2(data_loc2)

# %% [markdown]
# Below are the representations of action potentials found in control and PD mouse. Spike interface has an inbuilt tool to plot the channels. However, to know the amplitudes of the action potentials
# found in the recordings we have to take

# %%
full_raw_control.set_channel_groups(channel_ids=full_raw_control.get_channel_ids(), groups=[0,1])
plot_control = si.plot_traces(full_raw_control, time_range=(852.494, 852.499),mode='line',show_channel_ids=True, color_groups= True)

# %%
full_raw_PD.set_channel_groups(channel_ids=full_raw_PD.get_channel_ids(), groups=[0,1])
plot_PD = si.plot_traces(full_raw_PD, time_range=(813.246, 813.252),mode='line',show_channel_ids=True, color_groups= True)

# %% [markdown]
# An attribute finder which is based on any string character

# %%
def attributefinder(recording,strname):
    for attr in dir(recording):
        if strname in attr:
            print(attr)

# %%
attributefinder(full_raw_PD,"channel")
# Out:
# _channel_slice
# _remove_channels
# channel_ids
# channel_slice
# clear_channel_groups
# clear_channel_locations
# get_channel_gains
# get_channel_groups
# get_channel_ids
# get_channel_locations
# get_channel_offsets
# get_channel_property
# get_num_channels
# has_channel_location
# remove_channels
# rename_channels
# set_channel_gains
# set_channel_groups
# set_channel_locations
# set_channel_offsets

# %% [markdown]
# ## CED extractor method

# %%
stream_id = "0"

full_raw_PD_ced_1 = si.read_ced(data_loc2,stream_id=stream_id)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 stream_id = "0"
# ----> 3 full_raw_PD_ced_1 = si.read_ced(data_loc2,stream_id=stream_id)
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\extractors\neoextractors\ced.py:38, in CedRecordingExtractor.__init__(self, file_path, stream_id, stream_name, all_annotations)
#      36 def __init__(self, file_path, stream_id=None, stream_name=None, all_annotations=False):
#      37     neo_kwargs = self.map_to_neo_kwargs(file_path)
# ---> 38     NeoBaseRecordingExtractor.__init__(
#      39         self, stream_id=stream_id, stream_name=stream_name, all_annotations=all_annotations, **neo_kwargs
#      40     )
#      41     self._kwargs.update(dict(file_path=str(Path(file_path).absolute())))
#      42     self.extra_requirements.append("neo[ced]")
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\extractors\neoextractors\neobaseextractor.py:187, in NeoBaseRecordingExtractor.__init__(self, stream_id, stream_name, block_index, all_annotations, use_names_as_ids, **neo_kwargs)
#     158 def __init__(
#     159     self,
#     160     stream_id: Optional[str] = None,
#    (...)
#     165     **neo_kwargs: Dict[str, Any],
#     166 ) -> None:
#     167     """
#     168     Initialize a NeoBaseRecordingExtractor instance.
#     169
#    (...)
#     184
#     185     """
# --> 187     _NeoBaseExtractor.__init__(self, block_index, **neo_kwargs)
#     189     kwargs = dict(all_annotations=all_annotations)
#     190     if block_index is not None:
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\extractors\neoextractors\neobaseextractor.py:27, in _NeoBaseExtractor.__init__(self, block_index, **neo_kwargs)
#      23 def __init__(self, block_index, **neo_kwargs):
#      24
#      25     # Avoids double initiation of the neo reader if it was already done in the __init__ of the child class
#      26     if not hasattr(self, "neo_reader"):
# ---> 27         self.neo_reader = self.get_neo_io_reader(self.NeoRawIOClass, **neo_kwargs)
#      29     if self.neo_reader.block_count() > 1 and block_index is None:
#      30         raise Exception(
#      31             "This dataset is multi-block. Spikeinterface can load one block at a time. "
#      32             "Use 'block_index' to select the block to be loaded."
#      33         )
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\extractors\neoextractors\neobaseextractor.py:66, in _NeoBaseExtractor.get_neo_io_reader(cls, raw_class, **neo_kwargs)
#      64 neoIOclass = getattr(rawio_module, raw_class)
#      65 neo_reader = neoIOclass(**neo_kwargs)
# ---> 66 neo_reader.parse_header()
#      68 return neo_reader
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\neo\rawio\baserawio.py:189, in BaseRawIO.parse_header(self)
#     176 """
#     177 Parses the header of the file(s) to allow for faster computations
#     178 for all other functions
#     179
#     180 """
#     181 # this must create
#     182 # self.header['nb_block']
#     183 # self.header['nb_segment']
#    (...)
#     186 # self.header['spike_channels']
#     187 # self.header['event_channels']
# --> 189 self._parse_header()
#     190 self._check_stream_signal_channel_characteristics()
#     191 self.is_header_parsed = True
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\neo\rawio\cedrawio.py:71, in CedRawIO._parse_header(self)
#      70 def _parse_header(self):
# ---> 71     import sonpy
#      73     self.smrx_file = sonpy.lib.SonFile(sName=str(self.filename), bReadOnly=True)
#      74     smrx = self.smrx_file
#
# ModuleNotFoundError: No module named 'sonpy'

# %%
attributefinder(full_raw_PD_ced_1.neo_reader,"info")
# Out:
# stream_info

# %%
attributefinder(full_raw_PD.select_segments([0]),"frame")
# Out:
# _frame_slice
# frame_slice
# get_num_frames

# %%
full_raw_PD_ced_1.select_segments([0]).get_time_info()
# Out:
# {'sampling_frequency': 14814.814814814818, 't_start': 0.0, 'time_vector': None}

# %%
channeli_id = full_raw_PD.get_channel_ids()
print(channeli_id)
# Out:
# ['0' '2']

# %%
num_channels = full_raw_PD_ced_1.get_num_channels()
print(num_channels)
# Out:
# 1

# %%
linear_probe = generate_linear_probe(num_elec=1, ypitch=125)
plot_probe(linear_probe, with_contact_id=True)
# Out:
# (<matplotlib.collections.PolyCollection at 0x272605b4a00>,
#  <matplotlib.collections.PolyCollection at 0x2724d94cee0>)

# %%
linear_probe.set_contact_ids(contact_ids=channeli_id)
linear_probe.set_device_channel_indices(channel_indices=[0])

# %%
smr_rec_probe = full_raw_PD_ced_1.set_probe(linear_probe)

# %%
recording_f = si.bandpass_filter(smr_rec_probe, freq_min=1, freq_max=7000)
recording_cmr = si.common_reference(smr_rec_probe, reference='global', operator='median')

# %%
new_params = si.get_default_sorter_params("tridesclous2")
new_params["detection"]["detect_threshold"]=0.01
new_params["filtering"]["freq_max"] = 7000

# %%
new_params
# Out:
# {'apply_preprocessing': True,
#  'cache_preprocessing': {'mode': 'memory',
#   'memory_limit': 0.5,
#   'delete_cache': True},
#  'waveforms': {'ms_before': 0.5, 'ms_after': 1.5, 'radius_um': 120.0},
#  'filtering': {'freq_min': 300.0, 'freq_max': 7000},
#  'detection': {'peak_sign': 'neg',
#   'detect_threshold': 0.01,
#   'exclude_sweep_ms': 1.5,
#   'radius_um': 150.0},
#  'selection': {'n_peaks_per_channel': 5000, 'min_n_peaks': 20000},
#  'svd': {'n_components': 6},
#  'clustering': {'split_radius_um': 40.0,
#   'merge_radius_um': 40.0,
#   'threshold_diff': 1.5},
#  'templates': {'ms_before': 2.0, 'ms_after': 3.0, 'max_spikes_per_unit': 400},
#  'matching': {'method': 'circus-omp-svd', 'method_kwargs': {}},
#  'job_kwargs': {'n_jobs': -1},
#  'save_array': True}

# %% [markdown]
# Below faced problem while running tridesclous2 sorter using recording with ced extraction method. It does not work with latest python package as it runs on sonpy module which depends on the

# %%
from pathlib import Path
base_folder = Path(r"D:\sorting_folder")
sorting_tridesclous2_CED= si.run_sorter(sorter_name = "tridesclous2", recording=smr_rec_probe, output_folder=base_folder / 'results_tridesclous_PD_CED_1',**new_params)
# Out:
# d:\Anacondanew1\envs\Labproject\lib\site-packages\spikeinterface\preprocessing\normalize_scale.py:303: RuntimeWarning: divide by zero encountered in divide
#   gain = 1 / mads
# d:\Anacondanew1\envs\Labproject\lib\site-packages\spikeinterface\preprocessing\normalize_scale.py:304: RuntimeWarning: invalid value encountered in divide
#   offset = -medians / mads

# %% [markdown]
# ## Spike2 Extractor

# %%
#channel slicing for control group
control_channel_1 = full_raw_control.channel_slice(channel_ids=['0'])
control_channel_2 = full_raw_control.channel_slice(channel_ids=['2'])

# %%
gains = control_channel_1.get_channel_gains()
control_channel_1.set_channel_gains(gains)

# %%
mag1_control = control_channel_1.get_traces(return_scaled=True)[:]

time_control = control_channel_1.get_times()
plt.plot(time_control,mag1_control)

# %%
mag2_control = control_channel_2.get_traces(return_scaled=True)[:]

time2_control = control_channel_2.get_times()

plt.plot(time2_control,mag2_control)

# %%
#channel slicing for PD group
PD_channel1 = full_raw_PD.channel_slice(channel_ids=['0'])
PD_channel2 = full_raw_PD.channel_slice(channel_ids=['2'])

# %%
gains_PD = PD_channel1.get_channel_gains()
PD_channel1.set_channel_gains(gains_PD)

# %%
attributefinder(full_raw_PD,"index")
# Out:
# _check_segment_index
# block_index
# id_to_index
# sample_index_to_time
# stream_index
# time_to_sample_index

# %%
mag1 = PD_channel1.get_traces(return_scaled=True)[:]

time = PD_channel1.get_times()
plt.plot(time,mag1)

# %%
mag2 = PD_channel2.get_traces(return_scaled=True)[:]

time2 = PD_channel2.get_times()

plt.plot(time2,mag2)

# %% [markdown]
# ## Creating spike sorting for single channel recording

# %%
linear_probe_PD = generate_linear_probe(num_elec=1, ypitch=125)
plot_probe(linear_probe_PD, with_contact_id=True)
# Out:
# (<matplotlib.collections.PolyCollection at 0x1c618bcbf50>,
#  <matplotlib.collections.PolyCollection at 0x1c618be3910>)

# %%
linear_probe_PD.set_contact_ids(contact_ids=['0'])
linear_probe_PD.set_device_channel_indices(channel_indices=[0])

# %%
smr_rec_probe_PDchn1 = PD_channel1.set_probe(linear_probe_PD)

# %%
new_params = si.get_default_sorter_params("tridesclous2")
new_params["detection"]["detect_threshold"]=0.000001
new_params["filtering"]["freq_max"] = 7000

# %%
from pathlib import Path
base_folder = Path(r"D:\sorting_folder")
sorting_tridesclous2_PD_chn1= si.run_sorter(sorter_name = "tridesclous2", recording=smr_rec_probe_PDchn1, output_folder=base_folder / 'results_tridesclous_PD_channel1.3444557',**new_params)
# Out:
# d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\preprocessing\normalize_scale.py:303: RuntimeWarning: divide by zero encountered in divide
#   gain = 1 / mads
# d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\preprocessing\normalize_scale.py:304: RuntimeWarning: invalid value encountered in divide
#   offset = -medians / mads
# ---------------------------------------------------------------------------
# SpikeSortingError                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 from pathlib import Path
#       2 base_folder = Path(r"D:\sorting_folder")
# ----> 3 sorting_tridesclous2_PD_chn1= si.run_sorter(sorter_name = "tridesclous2", recording=smr_rec_probe_PDchn1, output_folder=base_folder / 'results_tridesclous_PD_channel1.3444557',**new_params)
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\sorters\runsorter.py:175, in run_sorter(sorter_name, recording, output_folder, remove_existing_folder, delete_output_folder, verbose, raise_error, docker_image, singularity_image, delete_container_files, with_output, **sorter_params)
#     168             container_image = singularity_image
#     169     return run_sorter_container(
#     170         container_image=container_image,
#     171         mode=mode,
#     172         **common_kwargs,
#     173     )
# --> 175 return run_sorter_local(**common_kwargs)
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\sorters\runsorter.py:225, in run_sorter_local(sorter_name, recording, output_folder, remove_existing_folder, delete_output_folder, verbose, raise_error, with_output, **sorter_params)
#     223 SorterClass.set_params_to_folder(recording, output_folder, sorter_params, verbose)
#     224 SorterClass.setup_recording(recording, output_folder, verbose=verbose)
# --> 225 SorterClass.run_from_folder(output_folder, raise_error, verbose)
#     226 if with_output:
#     227     sorting = SorterClass.get_result_from_folder(output_folder, register_recording=True, sorting_info=True)
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\sorters\basesorter.py:293, in BaseSorter.run_from_folder(cls, output_folder, raise_error, verbose)
#     290         print(f"{sorter_name} run time {run_time:0.2f}s")
#     292 if has_error and raise_error:
# --> 293     raise SpikeSortingError(
#     294         f"Spike sorting error trace:\n{log['error_trace']}\n"
#     295         f"Spike sorting failed. You can inspect the runtime trace in {output_folder}/spikeinterface_log.json."
#     296     )
#     298 return run_time
#
# SpikeSortingError: Spike sorting error trace:
# Traceback (most recent call last):
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\sorters\basesorter.py", line 258, in run_from_folder
#     SorterClass._run_from_folder(sorter_output_folder, sorter_params, verbose)
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\sorters\internal\tridesclous2.py", line 160, in _run_from_folder
#     tsvd.fit(wfs)
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\sklearn\decomposition\_truncated_svd.py", line 209, in fit
#     self.fit_transform(X)
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\sklearn\utils\_set_output.py", line 295, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\sklearn\decomposition\_truncated_svd.py", line 229, in fit_transform
#     X = self._validate_data(X, accept_sparse=["csr", "csc"], ensure_min_features=2)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\sklearn\base.py", line 633, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\sklearn\utils\validation.py", line 1072, in check_array
#     raise ValueError(
# ValueError: Found array with 0 sample(s) (shape=(0, 29)) while a minimum of 1 is required by TruncatedSVD.
#
# Spike sorting failed. You can inspect the runtime trace in D:\sorting_folder\results_tridesclous_PD_channel1.3444557/spikeinterface_log.json.

# %% [markdown]
# Even changing the version did not do anything, therefore the problem faced might be based on processing single channels.

# %%
# function creation

attributefinder(full_raw_PD.neo_reader,"info")
# Out:
# _channel_infos
# _global_info

# %%
full_raw_PD.neo_reader._channel_infos[1]["title"]
# Out:
# 'footshoc'

# %%
events = []
for i  in range(len(full_raw_PD.neo_reader._channel_infos)):
    if full_raw_PD.neo_reader._channel_infos[i]["t_start"]>0:
        events.append(full_raw_PD.neo_reader._channel_infos[i]["t_start"])
    else:
        continue

# %%
events
# Out:
# [3.2080625,
#  2.2499999999999998e-05,
#  0.08365,
#  0.0412725,
#  295.72972749999997,
#  3.2053024999999997]

# %%
data_loc = r"D:\GIPSA Labwork Internship\spiekee\Spikeme\sourcedata\520\ieeg\520-06.smr"
data_loc2 = r"D:\GIPSA Labwork Internship\spike_interface_primaries\RAWAT\Spikeme\Spikeme\sourcedata\502\ieeg\502-01.smr"
# Out:
# 32

# %%
def smr_to_bid_events(filename):
    smr_control = Spike2IO(filename)
    smr_control_ex = si.read_spike2(filename)
    block_control = smr_control.read_block(block_index=0,load_waveforms=True)
    times = block_control.segments[0].events[4].times
    sample_list = []
    for triggers in times:
        sample_list.append(smr_control_ex.time_to_sample_index(time_s=triggers))

    return sample_list

# %%
samples_obtained = smr_to_bid_events(data_loc)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\quantities\quantity.py:216, in Quantity.rescale(self, units, dtype)
#     215 try:
# --> 216     cf = get_conversion_factor(from_u, to_u)
#     217 except AssertionError:
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\quantities\quantity.py:52, in get_conversion_factor(from_u, to_u)
#      51 to_u = to_u._reference
# ---> 52 assert from_u.dimensionality == to_u.dimensionality
#      53 return from_u.magnitude / to_u.magnitude
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 samples_obtained = smr_to_bid_events(data_loc)
#
# Cell In[22], line 8, in smr_to_bid_events(filename)
#       6 sample_list = []
#       7 for triggers in times:
# ----> 8     sample_list.append(smr_control_ex.time_to_sample_index(time_s=triggers))
#      10 return sample_list
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\core\baserecording.py:441, in BaseRecording.time_to_sample_index(self, time_s, segment_index)
#     439 segment_index = self._check_segment_index(segment_index)
#     440 rs = self._recording_segments[segment_index]
# --> 441 return rs.time_to_sample_index(time_s)
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\spikeinterface\core\baserecording.py:726, in BaseRecordingSegment.time_to_sample_index(self, time_s)
#     724         sample_index = time_s * self.sampling_frequency
#     725     else:
# --> 726         sample_index = (time_s - self.t_start) * self.sampling_frequency
#     727 else:
#     728     sample_index = np.searchsorted(self.time_vector, time_s, side="right") - 1
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\quantities\quantity.py:62, in scale_other_units.<locals>.g(self, other, *args)
#      60     other = other.view(type=Quantity)
#      61 if other._dimensionality != self._dimensionality:
# ---> 62     other = other.rescale(self.units, dtype=np.result_type(self.dtype, other.dtype))
#      63 return f(self, other, *args)
#
# File d:\Anacondanew1\envs\scientificprogramming\Lib\site-packages\quantities\quantity.py:218, in Quantity.rescale(self, units, dtype)
#     216     cf = get_conversion_factor(from_u, to_u)
#     217 except AssertionError:
# --> 218     raise ValueError(
#     219         'Unable to convert between units of "%s" and "%s"'
#     220         %(from_u._dimensionality, to_u._dimensionality)
#     221     )
#     222 new_magnitude = cf*self.magnitude
#     223 dtype = np.result_type(dtype, new_magnitude)
#
# ValueError: Unable to convert between units of "dimensionless" and "s"

# %%
dir(Spike2IO(data_loc))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_all_data_blocks',
#  '_by_seg_data_blocks',
#  '_cache',
#  '_channel_infos',
#  '_check_stream_signal_channel_characteristics',
#  '_count_in_time_slice',
#  '_diskblock',
#  '_event_count',
#  '_generate_minimal_annotations',
#  '_get_analogsignal_chunk',
#  '_get_channel_indexes',
#  '_get_event_timestamps',
#  '_get_internal_timestamp_',
#  '_get_signal_size',
#  '_get_signal_t_start',
#  '_get_spike_raw_waveforms',
#  '_get_spike_timestamps',
#  '_get_stream_index_from_arg',
#  '_global_info',
#  '_memmap',
#  '_parse_header',
#  '_prefered_signal_group_mode',
#  '_repr_annotations',
#  '_rescale_epoch_duration',
#  '_rescale_event_timestamp',
#  '_rescale_spike_timestamp',
#  '_seg_t_starts',
#  '_seg_t_stops',
#  '_segment_t_start',
#  '_segment_t_stop',
#  '_several_channel_groups',
#  '_sig_dtypes',
#  '_sig_t_starts',
#  '_sig_t_stops',
#  '_source_name',
#  '_spike_count',
#  '_time_factor',
#  'add_in_cache',
#  'block_count',
#  'ced_units',
#  'channel_id_to_index',
#  'channel_name_to_index',
#  'description',
#  'dump_cache',
#  'event_channels_count',
#  'event_count',
#  'extensions',
#  'filename',
#  'get_analogsignal_chunk',
#  'get_event_timestamps',
#  'get_signal_sampling_rate',
#  'get_signal_size',
#  'get_signal_t_start',
#  'get_spike_raw_waveforms',
#  'get_spike_timestamps',
#  'get_sub_signal_streams',
#  'header',
#  'internal_unit_ids',
#  'is_header_parsed',
#  'is_readable',
#  'is_writable',
#  'logger',
#  'mode',
#  'name',
#  'parse_header',
#  'print_annotations',
#  'raw_annotations',
#  'rawmode',
#  'read',
#  'read_analogsignal',
#  'read_block',
#  'read_channelview',
#  'read_circularregionofinterest',
#  'read_epoch',
#  'read_event',
#  'read_group',
#  'read_imagesequence',
#  'read_irregularlysampledsignal',
#  'read_params',
#  'read_polygonregionofinterest',
#  'read_rectangularregionofinterest',
#  'read_segment',
#  'read_spiketrain',
#  'readable_objects',
#  'rescale_epoch_duration',
#  'rescale_event_timestamp',
#  'rescale_signal_raw_to_float',
#  'rescale_spike_timestamp',
#  'rescale_waveforms_to_float',
#  'segment_count',
#  'segment_t_start',
#  'segment_t_stop',
#  'setup_cache',
#  'signal_channels_count',
#  'signal_streams_count',
#  'source_name',
#  'spike_channels_count',
#  'spike_count',
#  'support_lazy',
#  'supported_objects',
#  'take_ideal_sampling_rate',
#  'try_signal_grouping',
#  'use_cache',
#  'write',
#  'write_analogsignal',
#  'write_block',
#  'write_channelview',
#  'write_circularregionofinterest',
#  'write_epoch',
#  'write_event',
#  'write_group',
#  'write_imagesequence',
#  'write_irregularlysampledsignal',
#  'write_params',
#  'write_polygonregionofinterest',
#  'write_rectangularregionofinterest',
#  'write_segment',
#  'write_spiketrain',
#  'writeable_objects']
