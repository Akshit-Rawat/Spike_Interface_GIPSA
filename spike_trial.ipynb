# %%
import neo as n 
import spikeinterface.full as si
import matplotlib.pyplot as plt

# %%
data_loc = r"D:\new project\Spikeme\Spikeme\sourcedata\520\ieeg\520-06.smr"

raw_sig = n.Spike2IO(data_loc)

# %%
block = raw_sig.read_block()

# %%
analogsig = block.segments[0].analogsignals[0]

# %%
M = analogsig.magnitude

# %%
T = analogsig.times

# %%
plt.plot(T,M)
